# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import io

# %%
data_fp = 'data/generated/2023-03-09_small_test.mat'

# %%
d = io.loadmat(data_fp)

# %%
d.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'train_features_singular_values', 'train_predictions', 'val_predictions', 'test_predictions', 'l2_reg_values', 'train_labels', 'val_labels', 'test_labels', 'random_weights', 'trained_weights'])

# %%
d['test_predictions'].shape
# Out:
# (7, 1000)

# %%
plt.plot(d['train_features_singular_values'].flatten(), '.')
plt.yscale('log')
plt.ylabel('Singular Values')
plt.show()
plt.clf()

# %%
plt.plot(d['train_predictions'][1].flatten(), d['train_labels'].flatten(), '.')
plt.xlabel('Train preds')
plt.ylabel('Train true')
plt.plot(plt.xlim(), plt.xlim(), '--', color='black')
plt.show()

# %%
x = d['train_predictions'][1].flatten()

# %%
print(x.max())
print(x.min())
# Out:
# 102.159775
# -165.93106

# %%
plt.plot(d['val_predictions'][1].flatten(), d['val_labels'].flatten(), '.')
plt.xlabel('Val preds')
plt.ylabel('Val true')
plt.plot(plt.xlim(), plt.xlim(), '--', color='black')
plt.show()
